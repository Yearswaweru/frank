# %% [markdown]
# <a href="https://colab.research.google.com/github/Yearswaweru/frank/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
frankline = pd.read_csv('/content/Road_Accident.csv')
print("shape of the dataset:", frankline.shape)
frankline.head(11)
# Out:
# shape of the dataset: (9, 9)
#   accident date weather conditions drunkudness  speeding condition of car  \
# 0     12/2/2023              sunny       0.00%        60             good
# 1      1/3/2023              misty      40.00%       110              bad
# 2      3/4/2023             cloudy      60.00%       140             good
# 3      4/4/2023              sunny      50.00%       100             good
# 4      6/6/2023              rainy       0.00%        50              bad
# 5     20/6/2023               calm      80.00%       140             good
# 6      3/7/2023              windy      10.00%       120             good
# 7     23/8/2023             cloudy      10.00%        70              bad
# 8    12/12/2023             cloudy      90.00%       150             good
#
#   accident class  casualty severity age of casualty type of car
# 0              D                  5   20 - 32 years    personal
# 1              A                  9        35 years    personal
# ...

# %%
import pandas as pd
frankline = pd.read_csv('/content/Road_Accident.csv')
data=frankline.loc[:,['speeding','casualty severity']]
data.head(11)
# Out:
#    speeding  casualty severity
# 0        60                  5
# 1       110                  9
# 2       140                 10
# 3       100                  7
# 4        50                  1
# 5       140                 14
# 6       120                 20
# 7        70                  3
# 8       150                 25

# %%
import pandas as pd
import matplotlib.pyplot as plt
frankline=pd.read_csv('/content/Road_Accident.csv')
frankline.plot(x='speeding',y='casualty severity',style='o')
plt.xlabel('speeding')
plt.ylabel('casualty severity')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
frankline = pd.read_csv('/content/Road_Accident.csv')
X = frankline [['speeding']]
y = frankline [ 'casualty severity']
regressor =LinearRegression()
regressor.fit(X, y)
frankline.plot(x='speeding', y='casualty severity', style= 'o', label='Data Points')
plt.plot(X, regressor.predict(X), color='red', linewidth=2, label='Regression Line')
plt.xlabel('speeding')
plt.ylabel('casualty severity')
plt.legend()
plt.show()

# %%
import pandas as pd
frankline = pd.read_csv('/content/Road_Accident.csv')
x=pd.DataFrame(data['speeding'])
y=pd.DataFrame(data['casualty severity'])

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
frankline = pd.read_csv('/content/Road_Accident.csv')
x=pd.DataFrame(data['speeding'])
y=pd.DataFrame(data['casualty severity'])
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (7, 1)
# (2, 1)
# (7, 1)
# (2, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
# Out:
# [-7.15254237]

# %%
print(regressor.coef_)
# Out:
# [[0.16779661]]

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([[18.01694915],
#        [16.33898305]])

# %%
y_test.head(11)
# Out:
#    casualty severity
# 8                 25
# 2                 10

# %%
from sklearn import metrics
import numpy as np
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("Mean Absolute Error (MSE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Error (MSE): 6.661016949152543
# Mean Squared Error (MSE): 44.47285262855503
# Root Mean Squared Error (RMSE): 6.668796940120087
