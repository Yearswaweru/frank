# %% [markdown]
# <a href="https://colab.research.google.com/github/Yearswaweru/frank/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
frankline = pd.read_csv('/content/election.csv')
print("shape of the dataset:", frankline.shape)
frankline.head(20)
# Out:
# shape of the dataset: (200, 5)
#     voters online behavior  Gender  Age  \
# 0                        1    Male   19
# 1                        2    Male   21
# 2                        3  Female   20
# 3                        4  Female   23
# 4                        5  Female   31
# 5                        6  Female   22
# 6                        7  Female   35
# 7                        8  Female   23
# 8                        9    Male   64
# 9                       10  Female   30
# 10                      11    Male   67
# 11                      12  Female   35
# 12                      13  Female   58
# 13                      14  Female   24
# 14                      15    Male   37
# 15                      16    Male   22
# 16                      17  Female   35
# 17                      18    Male   20
# 18                      19    Male   52
# 19                      20  Female   35
#
#     positive comments for trump while negative comments for hillary  \
# ...

# %%
import pandas as pd
frankline = pd.read_csv('/content/election.csv')
data=frankline.loc[:,['positive comments for trump while negative comments for hillary','positve comments for hillary while negative for trump']]
data.head(20)
# Out:
#     positive comments for trump while negative comments for hillary  \
# 0                                                  15
# 1                                                  15
# 2                                                  16
# 3                                                  16
# 4                                                  17
# 5                                                  17
# 6                                                  18
# 7                                                  18
# 8                                                  19
# 9                                                  19
# 10                                                 19
# 11                                                 19
# 12                                                 20
# 13                                                 20
# 14                                                 20
# 15                                                 20
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
frankline=pd.read_csv('/content/election.csv')
frankline.plot(x='positive comments for trump while negative comments for hillary',color='green',y='positve comments for hillary while negative for trump',style='o')
plt.xlabel('positive comments for trump while negative comments for hillary')
plt.ylabel('positve comments for hillary while negative for trump')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
frankline = pd.read_csv('/content/election.csv')
X = frankline [['positive comments for trump while negative comments for hillary']]
y = frankline [ 'positve comments for hillary while negative for trump']
regressor =LinearRegression()
regressor.fit(X, y)
frankline.plot(x='positive comments for trump while negative comments for hillary', y='positve comments for hillary while negative for trump', style= 'o', label='Data Points')
plt.plot(X, regressor.predict(X), color='red', linewidth=2, label='Regression Line')
plt.xlabel('positive comments for trump while negative comments for hillary')
plt.ylabel('positve comments for hillary while negative for trump')
plt.legend()
plt.show()

# %%
import pandas as pd
frankline = pd.read_csv('/content/election.csv')
x=pd.DataFrame(data['positive comments for trump while negative comments for hillary'])
y=pd.DataFrame(data['positve comments for hillary while negative for trump'])

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
frankline = pd.read_csv('/content/election.csv')
x=pd.DataFrame(data['positive comments for trump while negative comments for hillary'])
y=pd.DataFrame(data['positve comments for hillary while negative for trump'])
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (160, 1)
# (40, 1)
# (160, 1)
# (40, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
# Out:
# [46.98628462]

# %%
print(regressor.coef_)
# Out:
# [[0.07191139]]

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([[50.29420863],
#        [49.7189175 ],
#        [49.35936054],
#        [51.4447909 ],
#        [54.10551239],
#        [56.83814527],
#        [51.30096812],
#        [48.20877828],
#        [49.07171498],
#        [53.24257569],
#        [53.24257569],
#        [48.64024663],
#        [48.35260106],
#        [51.15714533],
#        [51.51670229],
#        [51.80434786],
#        [52.59537317],
#        [49.35936054],
#        [52.23581621],
#        [50.29420863],
#        [50.00656307],
#        [48.49642384],
#        [49.79082889],
#        [51.30096812],
#        [49.14362637],
#        [52.81110734],
#        [49.64700611],
#        [49.07171498],
#        [55.11227187],
#        [48.99980359],
#        [49.86274028],
#        [53.09875291],
#        [55.61565162],
#        [53.31448708],
#        [53.31448708],
#        [51.30096812],
#        [53.31448708],
#        [50.5818542 ],
#        [50.43803142],
#        [53.24257569]])

# %%
y_test.head(20)
# Out:
#      positve comments for hillary while negative for trump
# 58                                                  51
# 40                                                  35
# 34                                                  14
# 102                                                 59
# 184                                                 39
# 198                                                 18
# 95                                                  52
# 4                                                   40
# 29                                                  87
# 168                                                 27
# 171                                                 75
# 18                                                  29
# 11                                                  99
# 89                                                  46
# 110                                                 52
# 118                                                 43
# ...

# %%
from sklearn import metrics
import numpy as np
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("Mean Absolute Error (MSE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Error (MSE): 20.534409761191313
# Mean Squared Error (MSE): 644.8114855688806
# Root Mean Squared Error (RMSE): 25.393138552941434

# %%
import joblib
import pickle
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x,y)
joblib.dump(model, 'linear_regression_model.pkl')
with open ('linear_regression_model.pkl', 'wb') as file:
  pickle .dump(model, file)

# %%
import joblib
import numpy as np
import pandas as pd
new_X = np.array([20, 25, 30, 50, 70]).reshape(-1, 1)
model = joblib.load('linear_regression_model.pkl')
predictions = model.predict(new_X)
new_data = pd.DataFrame({'X': new_X. flatten(), 'Predicted_y': predictions. flatten()})
print(new_data)
# Out:
#     X  Predicted_y
# 0  20    49.805088
# 1  25    49.853770
# 2  30    49.902453
# 3  50    50.097183
# 4  70    50.291913
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
